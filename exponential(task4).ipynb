# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import hist
import seaborn as sns
rng = np.random.default_rng(0)

# %%
x1 = np.linspace(50, 70, 100)
y1 = 120 - x1

x2 = np.linspace(100, 120, 100)
y2 = 170 - x1

x3 = np.linspace(150, 170, 100)
y3 = 220 - x1

x4 = np.linspace(200, 220, 100)
y4 = 270 - x1

plt.plot(x1, y1, x2, y2, x3, y3, x4, y4)
plt.show()

# %%
# Set Numpy's RNG Constructor and seed value
rng = np.random.default_rng(42)

# Create z variables using linspace to create 20 data points
# Create x variable that rearranges the z values into the exponential distribution
# Create y variables that take z from x variables

# Repeat so that 4 datasets have been created
z5 = np.linspace(50, 70, 100)
x5 = rng.exponential(z5)
y5 = 120 - z5 

z6 = np.linspace(100, 120, 100) 
x6 = rng.exponential(z6)
y6 = 170 - z5

z7 = np.linspace(150, 170, 100)
x7 = rng.exponential(z7)
y7 = 220 - z5

z8 = np.linspace(200, 220, 100)
x8 = rng.exponential(z8)
y8 = 270 - z5

# Assign each dataset to a scattplot function, subbing in x and y values
a = plt.scatter(x=x5, y=y5)
b = plt.scatter(x=x6, y=y6)
c = plt.scatter(x=x7, y=y7)
d = plt.scatter(x=x8, y=y8)

# Plot line showing concentration of points across 4 datasets
line_x_all = [20, 20]
line_y_all = [50, 225]
line_all = plt.plot(line_x_all, line_y_all, color='black')

# Plot line show distributions of individual datasets
line_d_x = [0, 700]
line_d_y = [210, 210]
line_d = plt.plot(line_d_x, line_d_y, color='green')

line_c_x = [0, 700]
line_c_y = [160, 160]
line_c = plt.plot(line_c_x, line_c_y, color='yellow')

line_b_x = [0, 700]
line_b_y = [110, 110]
line_b = plt.plot(line_b_x, line_b_y, color='blue')

line_a_x = [0, 700]
line_a_y = [60, 60]
line_a = plt.plot(line_a_x, line_a_y, color='red')

# Add a legend for clarity
plt.legend((a, b, c, d),
           ('a', 'b', 'c', 'd'),
           scatterpoints=1,
           loc='right',
           ncol=3,
           fontsize=8)


plt.show()

# %%
E_df1 = pd.DataFrame( { "Exp. of x1": Ex1.ravel(), "Exp. of y1": Ey1.ravel() } )
E_df2 = pd.DataFrame( { "Exp. of x2": Ex1.ravel(), "Exp. of y2": Ey1.ravel()  } )
E_df3 = pd.DataFrame( { "Exp. of x3": Ex1.ravel(), "Exp. of y3": Ey1.ravel()  } )
E_df4 = pd.DataFrame( { "Exp. of x4": Ex1.ravel(), "Exp. of y4": Ey1.ravel()  } )

# %%
master = pd.DataFrame( { "Exp. of x1": Ex1.ravel(), "Exp. of y1": Ey1.ravel(), 
        "Exp. of x2": Ex1.ravel(), "Exp. of y2": Ey1.ravel(), 
        "Exp. of x3": Ex1.ravel(), "Exp. of y3": Ey1.ravel(), 
        "Exp. of x4": Ex1.ravel(), "Exp. of y4": Ey1.ravel()  } )

# %%
master
# Out:
#     Exp. of x1  Exp. of y1  Exp. of x2  Exp. of y2  Exp. of x3  Exp. of y3  \
# 0   120.210430   70.000000  120.210430   70.000000  120.210430   70.000000
# 1   117.281440   69.797980  117.281440   69.797980  117.281440   69.797980
# 2   120.201590   69.595960  120.201590   69.595960  120.201590   69.595960
# 3    14.159287   69.393939   14.159287   69.393939   14.159287   69.393939
# 4     4.391718   69.191919    4.391718   69.191919    4.391718   69.191919
# ..         ...         ...         ...         ...         ...         ...
# 95   36.742266   50.808081   36.742266   50.808081   36.742266   50.808081
# 96   21.153415   50.606061   21.153415   50.606061   21.153415   50.606061
# 97    5.271107   50.404040    5.271107   50.404040    5.271107   50.404040
# 98   35.147457   50.202020   35.147457   50.202020   35.147457   50.202020
# 99  157.631500   50.000000  157.631500   50.000000  157.631500   50.000000
#
#     Exp. of x4  Exp. of y4
# 0   120.210430   70.000000
# ...

# %%
sns.scatterplot(x =["Exp. of x1"], y=["Exp. of y1"], data=master)
sns.scatterplot(x =["Exp. of x2"], y=["Exp. of y2"], data=master)
sns.scatterplot(x =["Exp. of x3"], y=["Exp. of y3"], data=master)
sns.scatterplot(x =["Exp. of x4"], y=["Exp. of y4"], data=master)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-e228ed0be034> in <module>
# ----> 1 sns.scatterplot(x =["Exp. of x1"], y=["Exp. of y1"], data=master)
#       2 sns.scatterplot(x =["Exp. of x2"], y=["Exp. of y2"], data=master)
#       3 sns.scatterplot(x =["Exp. of x3"], y=["Exp. of y3"], data=master)
#       4 sns.scatterplot(x =["Exp. of x4"], y=["Exp. of y4"], data=master)
#       5 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1388                 legend="brief", ax=None, **kwargs):
#    1389
# -> 1390     p = _ScatterPlotter(
#    1391         x=x, y=y, hue=hue, style=style, size=size, data=data,
# ...

# %%
# Plot line show distributions of individual datasets
line_d_x = [0, 700]
line_d_y = [210, 210]
line_d = plt.plot(line_d_x, line_d_y, color='green')

line_c_x = [0, 700]
line_c_y = [160, 160]
line_c = plt.plot(line_c_x, line_c_y, color='yellow')

line_b_x = [0, 700]
line_b_y = [110, 110]
line_b = plt.plot(line_b_x, line_b_y, color='blue')

line_a_x = [0, 700]
line_a_y = [60, 60]
line_a = plt.plot(line_a_x, line_a_y, color='red')
