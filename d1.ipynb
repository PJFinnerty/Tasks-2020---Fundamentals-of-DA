# %%
rng = np.random.default_rng(0)
x1 = np.linspace(1, 20, 100)
x1_r = rng.permutation(x1)
a1 = 2
b1 = 4
y1 = a1 * x1 + b1
plt.plot(x1, y1)
plt.show()

# %%
rng = np.random.default_rng(0)
x2 = np.linspace(20, 40, 100)
x2_r = rng.permutation(x2)
a2 = 5
b2 = 7
y2 = a2 * x2 + b2
plt.plot(x1, y1, x2, y2)
plt.show()

# %%
rng = np.random.default_rng(0)
x3 = np.linspace(40, 60, 100)
x3_r = rng.permutation(x3)
a3 = 8
b3 = 10
y3 = a3 * x3 + b3
plt.plot(x1, y1, x2, y2, x3, y3)
plt.show()

# %%
rng = np.random.default_rng(0)
x4 = np.linspace(60, 80, 100)
x4_r = rng.permutation(x4)
a4 = 11
b4 = 13
y4 = a4 * x4 + b4
plt.plot(x1, y1, x2, y2, x3, y3, x4, y4)
plt.show()

# %%
rng = np.random.default_rng(0)
df1_r = pd.DataFrame({'x1': x1.ravel(), 'y1': y1.ravel()})
df2_r = pd.DataFrame({'x2': x2.ravel(), 'y2': y2.ravel()})
df3_r = pd.DataFrame({'x3': x3.ravel(), 'y3': y3.ravel()})
df4_r = pd.DataFrame({'x4': x4.ravel(), 'y4': y4.ravel()})

# %%
rng = np.random.default_rng(0)
x1 = np.linspace(1, 20, 100)
x1_r = rng.permutation(x1)
a1 = 2
b1 = 4
y1 = a1 * x1 + b1
plt.plot(x1, y1)
plt.show()

# %%
rng = np.random.default_rng(0)
x2 = np.linspace(20, 40, 100)
x2_r = rng.permutation(x2)
a2 = 5
b2 = 7
y2 = a2 * x2 + b2
plt.plot(x1, y1, x2, y2)
plt.show()

# %%
rng = np.random.default_rng(0)
x3 = np.linspace(40, 60, 100)
x3_r = rng.permutation(x3)
a3 = 8
b3 = 10
y3 = a3 * x3 + b3
plt.plot(x1, y1, x2, y2, x3, y3)
plt.show()

# %%
rng = np.random.default_rng(0)
x4 = np.linspace(60, 80, 100)
x4_r = rng.permutation(x4)
a4 = 11
b4 = 13
y4 = a4 * x4 + b4
plt.plot(x1, y1, x2, y2, x3, y3, x4, y4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dddf5b3c9353> in <module>
# ----> 1 rng = np.random.default_rng(0)
#       2 x4 = np.linspace(60, 80, 100)
#       3 x4_r = rng.permutation(x4)
#       4 a4 = 11
#       5 b4 = 13
#
# NameError: name 'np' is not defined

# %%
rng = np.random.default_rng(0)
df1_r = pd.DataFrame({'x1': x1.ravel(), 'y1': y1.ravel()})
df2_r = pd.DataFrame({'x2': x2.ravel(), 'y2': y2.ravel()})
df3_r = pd.DataFrame({'x3': x3.ravel(), 'y3': y3.ravel()})
df4_r = pd.DataFrame({'x4': x4.ravel(), 'y4': y4.ravel()})

# %%
rng = np.random.default_rng(0)
x1 = np.linspace(1, 20, 100)
x1_r = rng.permutation(x1)
a1 = 2
b1 = 4
y1 = a1 * x1 + b1
plt.plot(x1, y1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-28823aa25bc5> in <module>
# ----> 1 rng = np.random.default_rng(0)
#       2 x1 = np.linspace(1, 20, 100)
#       3 x1_r = rng.permutation(x1)
#       4 a1 = 2
#       5 b1 = 4
#
# NameError: name 'np' is not defined

# %%
rng = np.random.default_rng(0)
x2 = np.linspace(20, 40, 100)
x2_r = rng.permutation(x2)
a2 = 5
b2 = 7
y2 = a2 * x2 + b2
plt.plot(x1, y1, x2, y2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-45b292c50166> in <module>
# ----> 1 rng = np.random.default_rng(0)
#       2 x2 = np.linspace(20, 40, 100)
#       3 x2_r = rng.permutation(x2)
#       4 a2 = 5
#       5 b2 = 7
#
# NameError: name 'np' is not defined

# %%
rng = np.random.default_rng(0)
x3 = np.linspace(40, 60, 100)
x3_r = rng.permutation(x3)
a3 = 8
b3 = 10
y3 = a3 * x3 + b3
plt.plot(x1, y1, x2, y2, x3, y3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0d30ec55adb5> in <module>
# ----> 1 rng = np.random.default_rng(0)
#       2 x3 = np.linspace(40, 60, 100)
#       3 x3_r = rng.permutation(x3)
#       4 a3 = 8
#       5 b3 = 10
#
# NameError: name 'np' is not defined

# %%
rng = np.random.default_rng(0)
x4 = np.linspace(60, 80, 100)
x4_r = rng.permutation(x4)
a4 = 11
b4 = 13
y4 = a4 * x4 + b4
plt.plot(x1, y1, x2, y2, x3, y3, x4, y4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-dddf5b3c9353> in <module>
# ----> 1 rng = np.random.default_rng(0)
#       2 x4 = np.linspace(60, 80, 100)
#       3 x4_r = rng.permutation(x4)
#       4 a4 = 11
#       5 b4 = 13
#
# NameError: name 'np' is not defined

# %%
rng = np.random.default_rng(0)
df1_r = pd.DataFrame({'x1': x1.ravel(), 'y1': y1.ravel()})
df2_r = pd.DataFrame({'x2': x2.ravel(), 'y2': y2.ravel()})
df3_r = pd.DataFrame({'x3': x3.ravel(), 'y3': y3.ravel()})
df4_r = pd.DataFrame({'x4': x4.ravel(), 'y4': y4.ravel()})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f255674391fe> in <module>
# ----> 1 rng = np.random.default_rng(0)
#       2 df1_r = pd.DataFrame({'x1': x1.ravel(), 'y1': y1.ravel()})
#       3 df2_r = pd.DataFrame({'x2': x2.ravel(), 'y2': y2.ravel()})
#       4 df3_r = pd.DataFrame({'x3': x3.ravel(), 'y3': y3.ravel()})
#       5 df4_r = pd.DataFrame({'x4': x4.ravel(), 'y4': y4.ravel()})
#
# NameError: name 'np' is not defined

# %%
rng = np.random.default_rng(0)
x1 = np.linspace(1, 20, 100)
x1_r = rng.permutation(x1)
a1 = 2
b1 = 4
y1 = a1 * x1 + b1
plt.plot(x1, y1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-28823aa25bc5> in <module>
# ----> 1 rng = np.random.default_rng(0)
#       2 x1 = np.linspace(1, 20, 100)
#       3 x1_r = rng.permutation(x1)
#       4 a1 = 2
#       5 b1 = 4
#
# NameError: name 'np' is not defined

# %%
rng = np.random.default_rng(0)
x2 = np.linspace(20, 40, 100)
x2_r = rng.permutation(x2)
a2 = 5
b2 = 7
y2 = a2 * x2 + b2
plt.plot(x1, y1, x2, y2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-45b292c50166> in <module>
# ----> 1 rng = np.random.default_rng(0)
#       2 x2 = np.linspace(20, 40, 100)
#       3 x2_r = rng.permutation(x2)
#       4 a2 = 5
#       5 b2 = 7
#
# NameError: name 'np' is not defined

# %%
rng = np.random.default_rng(0)
x3 = np.linspace(40, 60, 100)
x3_r = rng.permutation(x3)
a3 = 8
b3 = 10
y3 = a3 * x3 + b3
plt.plot(x1, y1, x2, y2, x3, y3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0d30ec55adb5> in <module>
# ----> 1 rng = np.random.default_rng(0)
#       2 x3 = np.linspace(40, 60, 100)
#       3 x3_r = rng.permutation(x3)
#       4 a3 = 8
#       5 b3 = 10
#
# NameError: name 'np' is not defined

# %%
rng = np.random.default_rng(0)
x4 = np.linspace(60, 80, 100)
x4_r = rng.permutation(x4)
a4 = 11
b4 = 13
y4 = a4 * x4 + b4
plt.plot(x1, y1, x2, y2, x3, y3, x4, y4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-dddf5b3c9353> in <module>
# ----> 1 rng = np.random.default_rng(0)
#       2 x4 = np.linspace(60, 80, 100)
#       3 x4_r = rng.permutation(x4)
#       4 a4 = 11
#       5 b4 = 13
#
# NameError: name 'np' is not defined

# %%
rng = np.random.default_rng(0)
df1_r = pd.DataFrame({'x1': x1.ravel(), 'y1': y1.ravel()})
df2_r = pd.DataFrame({'x2': x2.ravel(), 'y2': y2.ravel()})
df3_r = pd.DataFrame({'x3': x3.ravel(), 'y3': y3.ravel()})
df4_r = pd.DataFrame({'x4': x4.ravel(), 'y4': y4.ravel()})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f255674391fe> in <module>
# ----> 1 rng = np.random.default_rng(0)
#       2 df1_r = pd.DataFrame({'x1': x1.ravel(), 'y1': y1.ravel()})
#       3 df2_r = pd.DataFrame({'x2': x2.ravel(), 'y2': y2.ravel()})
#       4 df3_r = pd.DataFrame({'x3': x3.ravel(), 'y3': y3.ravel()})
#       5 df4_r = pd.DataFrame({'x4': x4.ravel(), 'y4': y4.ravel()})
#
# NameError: name 'np' is not defined
